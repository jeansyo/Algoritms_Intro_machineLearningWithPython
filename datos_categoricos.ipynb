# %% [markdown]
# <a href="https://colab.research.google.com/github/Jean-Rd/Algoritms_Intro_machineLearningWithPython/blob/master/datos_categoricos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
boston = load_boston()

feature = list(boston.feature_names)+['target']
data = boston.data
dta = np.hstack((boston.data, target))

df = pd.DataFrame(dta, columns=feature)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  target
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98    24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14    21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03    34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94    33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33    36.2
#
# [5 rows x 14 columns]

# %%
# Encontrar valores duplicados
duplicated = df.duplicated(subset='target', keep=False)
# devuelve una columna boolean, donde estan los datos segun keep si son duplicados o no

# Ordenar valores duplicados
duplicated_target = df[duplicated].sort_values('target')
# busca en df los valores de duplicated y los ordena de menora  a mayor(la matriz solo almacena los valores repetidos)

# imprimir columnas relevantes o duplicadas
print(duplicated_target[['CRIM', 'AGE', 'INDUS', 'target']])
# Out:
#          CRIM    AGE  INDUS  target
# 405  67.92080  100.0  18.10     5.0
# 398  38.35180  100.0  18.10     5.0
# 489   0.18337   98.3  27.74     7.0
# 414  45.74610  100.0  18.10     7.0
# 401  14.23620  100.0  18.10     7.2
# ..        ...    ...    ...     ...
# 283   0.01501   24.8   1.21    50.0
# 257   0.61154   86.9   3.97    50.0
# 267   0.57834   67.0   3.97    50.0
# 161   1.46336   90.8  19.58    50.0
# 371   9.23230  100.0  18.10    50.0
#
# [406 rows x 4 columns]

# %%
# eliminar datos de df y almacenar los resultados en _data
_data = df.drop_duplicates(subset='target')
_data
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  target
# 0     0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98    24.0
# 1     0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14    21.6
# 2     0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03    34.7
# 3     0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94    33.4
# 4     0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33    36.2
# ..        ...   ...    ...   ...    ...  ...    ...      ...     ...    ...     ...
# 460   4.81213   0.0  18.10   0.0  0.713  ...  666.0     20.2  255.23  16.42    16.4
# 461   3.69311   0.0  18.10   0.0  0.713  ...  666.0     20.2  391.43  14.65    17.7
# 477  15.02340   0.0  18.10   0.0  0.614  ...  666.0     20.2  349.48  24.91    12.0
# 483   2.81838   0.0  18.10   0.0  0.532  ...  666.0     20.2  392.92  10.42    21.8
# ...

# %%
_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 0 to 490
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     229 non-null    float64
#  1   ZN       229 non-null    float64
#  2   INDUS    229 non-null    float64
#  3   CHAS     229 non-null    float64
#  4   NOX      229 non-null    float64
#  5   RM       229 non-null    float64
#  6   AGE      229 non-null    float64
#  7   DIS      229 non-null    float64
#  8   RAD      229 non-null    float64
#  9   TAX      229 non-null    float64
#  10  PTRATIO  229 non-null    float64
#  11  B        229 non-null    float64
#  12  LSTAT    229 non-null    float64
#  13  target   229 non-null    float64
# dtypes: float64(14)
# memory usage: 26.8 KB

# %%
_data['target'] = _data['target'].astype(str)
_data.info()
_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 0 to 490
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     229 non-null    float64
#  1   ZN       229 non-null    float64
#  2   INDUS    229 non-null    float64
#  3   CHAS     229 non-null    float64
#  4   NOX      229 non-null    float64
#  5   RM       229 non-null    float64
#  6   AGE      229 non-null    float64
#  7   DIS      229 non-null    float64
#  8   RAD      229 non-null    float64
#  9   TAX      229 non-null    float64
#  10  PTRATIO  229 non-null    float64
#  11  B        229 non-null    float64
#  12  LSTAT    229 non-null    float64
#  13  target   229 non-null    object
# dtypes: float64(13), object(1)
# memory usage: 26.8+ KB
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Second part of Data Cleaning
from sklearn.datasets import load_wine

wine = load_wine()
columns = wine.feature_names + ['target']
data = wine.data
target = wine.target[:, np.newaxis]
#dta = np.hstack((data, target))
dta = np.hstack((wine.data, wine.target[:, np.newaxis]))

wine_df = pd.DataFrame(dta, columns=columns)
wine_df.head()
# Out:
#    alcohol  malic_acid   ash  ...  od280/od315_of_diluted_wines  proline  target
# 0    14.23        1.71  2.43  ...                          3.92   1065.0     0.0
# 1    13.20        1.78  2.14  ...                          3.40   1050.0     0.0
# 2    13.16        2.36  2.67  ...                          3.17   1185.0     0.0
# 3    14.37        1.95  2.50  ...                          3.45   1480.0     0.0
# 4    13.24        2.59  2.87  ...                          2.93    735.0     0.0
#
# [5 rows x 14 columns]

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
wine_df.target = wine_df.target.astype(int)
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
wine_df[wine_df.target.isin([0])]
# probar con 1 and 2
# Out:
#     alcohol  malic_acid   ash  ...  od280/od315_of_diluted_wines  proline  target
# 0     14.23        1.71  2.43  ...                          3.92   1065.0       0
# 1     13.20        1.78  2.14  ...                          3.40   1050.0       0
# 2     13.16        2.36  2.67  ...                          3.17   1185.0       0
# 3     14.37        1.95  2.50  ...                          3.45   1480.0       0
# 4     13.24        2.59  2.87  ...                          2.93    735.0       0
# 5     14.20        1.76  2.45  ...                          2.85   1450.0       0
# 6     14.39        1.87  2.45  ...                          3.58   1290.0       0
# 7     14.06        2.15  2.61  ...                          3.58   1295.0       0
# 8     14.83        1.64  2.17  ...                          2.85   1045.0       0
# 9     13.86        1.35  2.27  ...                          3.55   1045.0       0
# ...

# %%
# meetodo unique, es que busca los valores unicos en el dta fram

wine_df.target.unique()
# Out:
# array([0, 1, 2])

# %%
wine_df.target.value_counts()
# Out:
# 1    71
# 0    59
# 2    48
# Name: target, dtype: int64

# %%
wine_df.magnesium.unique()
# Out:
# array([127., 100., 101., 113., 118., 112.,  96., 121.,  97.,  98., 105.,
#         95.,  89.,  91., 102., 120., 115., 108., 116., 126., 124.,  93.,
#         94., 107., 106., 104., 132., 110., 128., 117.,  90., 103., 111.,
#         92.,  88.,  87.,  78., 151.,  86., 139., 136.,  85.,  99.,  84.,
#         70.,  81.,  80., 162., 134., 119.,  82., 122., 123.])
