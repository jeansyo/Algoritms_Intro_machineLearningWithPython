# %% [markdown]
# <a href="https://colab.research.google.com/github/Jean-Rd/Algoritms_Intro_machineLearningWithPython/blob/master/Recordando_Reg_Lin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_boston
import numpy as np
import matplotlib.pyplot as plt

# %%
boston = load_boston()

# %%
_X = np.array(boston.data[:,5])
_Y = np.array(boston.target)

plt.scatter(_X, _Y, alpha=.5)

_X = np.array([np.ones(506), _X]).T

b = np.linalg.inv(_X.T @ _X) @ _X.T @ _Y

plt.plot([4, 9], [b[0] + b[1] * 4, b[0] + b[1] * 9], c='red')
plt.show()

# %%
# Out:
# (2,)
