# %%
import numpy as np
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
n_neighbors = 15

_X = iris.data[:,:2]
_Y = iris.target

_H = .02

# %%
cmap_light = ListedColormap(['orange', 'cyan', 'cornflowerblue'])
cmap_bold = ListedColormap(['darkorange', 'c', 'darkblue'])

# %%
for weights in ['uniform','distance']:
    
    clf = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights).fit(_X,_Y)
    
    x_min, x_max = _X[:,0].min() - 1, _X[:,0].max() + 1
    
    y_min, y_max = _X[:,1].min() - 1, _X[:,1].max() + 1
    
    xx, yy = np.meshgrid(np.arange(x_min, x_max, _H), np.arange(y_min, y_max, _H))
    
    
    _Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    _Z = _Z.reshape(xx.shape)

    plt.figure()
    plt.pcolormesh(xx, yy, _Z, cmap=cmap_light)
    
    
    plt.scatter(_X[:,0], _X[:,1], c=_Y, cmap=cmap_bold, edgecolor='k', s=20)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title('3D-Class Classification (k={}, weights={})'.format(n_neighbors, weights))
    
plt.show()

# %%
a = np.c_[np.array([1,2,3]), np.array([4,5,6])]
a 
# ESTO ES LO QUE HACE np.c_[_x, _y, _z...]
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])
