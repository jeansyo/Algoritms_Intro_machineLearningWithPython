# %%
import pandas as pd

# %%
df = pd.read_excel(r'csv/precios_mayoristas1996.xls')

# %%
df.head()
# Out:
#   Serie histórica del sistema de índices de precios mayoristas (SIPM) base 1993 = 100 desde 1996 en adelante  \
# 0  Nivel general y principales aperturas de cada ...
# 1                                                NaN
# 2                                          Año y mes
# 3                                                NaN
# 4                                                NaN
#
#                                        Unnamed: 1 Unnamed: 2  \
# 0                                             NaN        NaN
# 1                                             NaN        NaN
# 2  Índice de precios internos al por mayor (IPIM)        NaN
# 3                                           Nivel        NaN
# 4                                         general      Total
#
#              Unnamed: 3        Unnamed: 4  Unnamed: 5  \
# 0                   NaN               NaN         NaN
# 1                   NaN               NaN         NaN
# ...
